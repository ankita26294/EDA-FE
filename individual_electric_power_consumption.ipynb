# %% [markdown]
# # Individual-household_electric-power consumption

# %% [markdown]
# Dataset link:
#     https://archive.ics.uci.edu/ml/datasets/individual+household+electric+power+consumption

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df=pd.read_csv(r'C:\Users\hp\EDA and FE\household_power_consumption.txt',delimiter=";",usecols=['Date','Time','Global_active_power','Global_reactive_power','Voltage','Global_intensity','Sub_metering_1','Sub_metering_2','Sub_metering_3'])

# %%
df.head()
# Out:
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00               4.216                 0.418  234.840
# 1  16/12/2006  17:25:00               5.360                 0.436  233.630
# 2  16/12/2006  17:26:00               5.374                 0.498  233.290
# 3  16/12/2006  17:27:00               5.388                 0.502  233.740
# 4  16/12/2006  17:28:00               3.666                 0.528  235.680
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 0           18.400          0.000          1.000            17.0
# 1           23.000          0.000          1.000            16.0
# 2           23.000          0.000          2.000            17.0
# 3           23.000          0.000          1.000            17.0
# 4           15.800          0.000          1.000            17.0

# %%
df.tail()
# Out:
#                Date      Time Global_active_power Global_reactive_power  \
# 2075254  26/11/2010  20:58:00               0.946                     0
# 2075255  26/11/2010  20:59:00               0.944                     0
# 2075256  26/11/2010  21:00:00               0.938                     0
# 2075257  26/11/2010  21:01:00               0.934                     0
# 2075258  26/11/2010  21:02:00               0.932                     0
#
#         Voltage Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 2075254  240.43                4              0              0             0.0
# 2075255     240                4              0              0             0.0
# 2075256  239.82              3.8              0              0             0.0
# 2075257   239.7              3.8              0              0             0.0
# 2075258  239.55              3.8              0              0             0.0

# %% [markdown]
# # Attribute Information:
#
# 1.date: Date in format dd/mm/yyyy
# 2.time: time in format hh:mm:ss
# 3.global_active_power: household global minute-averaged active power (in kilowatt)
# 4.global_reactive_power: household global minute-averaged reactive power (in kilowatt)
# 5.voltage: minute-averaged voltage (in volt)
# 6.global_intensity: household global minute-averaged current intensity (in ampere)
# 7.sub_metering_1: energy sub-metering No. 1 (in watt-hour of active energy). It corresponds to the kitchen, containing mainly a dishwasher, an oven and a microwave (hot plates are not electric but gas powered).
# 8.sub_metering_2: energy sub-metering No. 2 (in watt-hour of active energy). It corresponds to the laundry room, containing a washing-machine, a tumble-drier, a refrigerator and a light.
# 9.sub_metering_3: energy sub-metering No. 3 (in watt-hour of active energy). It corresponds to an electric water-heater and an air-conditioner.

# %% [markdown]
# Take a sample data of 50000

# %%
df=df.sample(n=50000)

# %%
df.shape
# Out:
# (50000, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 245473 to 1691350
# Data columns (total 9 columns):
# Date                     50000 non-null object
# Time                     50000 non-null object
# Global_active_power      50000 non-null object
# Global_reactive_power    50000 non-null object
# Voltage                  50000 non-null object
# Global_intensity         50000 non-null object
# Sub_metering_1           50000 non-null object
# Sub_metering_2           50000 non-null object
# Sub_metering_3           49366 non-null float64
# dtypes: float64(1), object(8)
# memory usage: 3.8+ MB

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Global_active_power', 'Global_reactive_power',
#        'Voltage', 'Global_intensity', 'Sub_metering_1', 'Sub_metering_2',
#        'Sub_metering_3'],
#       dtype='object')

# %% [markdown]
# # Drop missing values

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#               Date      Time Global_active_power Global_reactive_power  \
# 245473    5/6/2007  04:37:00               0.258                 0.094
# 1723138  27/3/2010  08:22:00               0.348                 0.000
# 175594   17/4/2007  15:58:00               0.164                 0.000
# 920574   16/9/2008  00:18:00               0.204                 0.000
# 1741570   9/4/2010  03:34:00               0.330                 0.102
# ...            ...       ...                 ...                   ...
# 147883   29/3/2007  10:07:00               1.418                 0.202
# 384656    9/9/2007  20:20:00               1.558                 0.170
# 1752127  16/4/2010  11:31:00               0.420                 0.186
# 1319633  20/6/2009  03:17:00               0.312                 0.222
# 1691350   5/3/2010  06:34:00               0.540                 0.112
#
#          Voltage Global_intensity Sub_metering_1 Sub_metering_2  \
# ...

# %%
df.shape
# Out:
# (49366, 9)

# %% [markdown]
# # Convert all data type for each columns

# %%
df=df.astype({'Global_active_power':'float','Global_reactive_power':'float','Voltage':'float', 'Global_intensity':'float', 'Sub_metering_1':'float', 'Sub_metering_2':'float'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49366 entries, 245473 to 1691350
# Data columns (total 9 columns):
# Date                     49366 non-null object
# Time                     49366 non-null object
# Global_active_power      49366 non-null float64
# Global_reactive_power    49366 non-null float64
# Voltage                  49366 non-null float64
# Global_intensity         49366 non-null float64
# Sub_metering_1           49366 non-null float64
# Sub_metering_2           49366 non-null float64
# Sub_metering_3           49366 non-null float64
# dtypes: float64(7), object(2)
# memory usage: 3.8+ MB

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df['Time']=pd.to_datetime(df['Time'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49366 entries, 245473 to 1691350
# Data columns (total 9 columns):
# Date                     49366 non-null datetime64[ns]
# Time                     49366 non-null datetime64[ns]
# Global_active_power      49366 non-null float64
# Global_reactive_power    49366 non-null float64
# Voltage                  49366 non-null float64
# Global_intensity         49366 non-null float64
# Sub_metering_1           49366 non-null float64
# Sub_metering_2           49366 non-null float64
# Sub_metering_3           49366 non-null float64
# dtypes: datetime64[ns](2), float64(7)
# memory usage: 3.8 MB

# %%
df.head()
# Out:
#               Date                Time  Global_active_power  \
# 245473  2007-05-06 2022-10-31 04:37:00                0.258
# 1723138 2010-03-27 2022-10-31 08:22:00                0.348
# 175594  2007-04-17 2022-10-31 15:58:00                0.164
# 920574  2008-09-16 2022-10-31 00:18:00                0.204
# 1741570 2010-09-04 2022-10-31 03:34:00                0.330
#
#          Global_reactive_power  Voltage  Global_intensity  Sub_metering_1  \
# 245473                   0.094   236.03               1.0             0.0
# 1723138                  0.000   241.31               1.4             0.0
# 175594                   0.000   243.72               0.8             0.0
# 920574                   0.000   244.45               1.0             0.0
# 1741570                  0.102   241.66               1.4             0.0
#
#          Sub_metering_2  Sub_metering_3
# 245473              1.0             0.0
# 1723138             0.0             0.0
# ...

# %%
df['year']=df['Date'].dt.year
df['month']=df['Date'].dt.month
df['days']=df['Date'].dt.day

# %%
df['time']=df['Time'].dt.time
df['Hour']=df['Time'].dt.hour
df['minutes']=df['Time'].dt.minute

# %%
df.head()
# Out:
#               Date                Time  Global_active_power  \
# 245473  2007-05-06 2022-10-31 04:37:00                0.258
# 1723138 2010-03-27 2022-10-31 08:22:00                0.348
# 175594  2007-04-17 2022-10-31 15:58:00                0.164
# 920574  2008-09-16 2022-10-31 00:18:00                0.204
# 1741570 2010-09-04 2022-10-31 03:34:00                0.330
#
#          Global_reactive_power  Voltage  Global_intensity  Sub_metering_1  \
# 245473                   0.094   236.03               1.0             0.0
# 1723138                  0.000   241.31               1.4             0.0
# 175594                   0.000   243.72               0.8             0.0
# 920574                   0.000   244.45               1.0             0.0
# 1741570                  0.102   241.66               1.4             0.0
#
#          Sub_metering_2  Sub_metering_3  year  month  days      time  Hour  \
# 245473              1.0             0.0  2007      5     6  04:37:00     4
# ...

# %%
df['Total_metering']=df['Sub_metering_1']+df['Sub_metering_2']+df['Sub_metering_3']

# %%
df['Total_metering']
# Out:
# 245473      1.0
# 1723138     0.0
# 175594      0.0
# 920574      1.0
# 1741570     1.0
#            ...
# 147883     19.0
# 384656     18.0
# 1752127     1.0
# 1319633     1.0
# 1691350     1.0
# Name: Total_metering, Length: 49366, dtype: float64

# %%
df.head()
# Out:
#               Date                Time  Global_active_power  \
# 245473  2007-05-06 2022-10-31 04:37:00                0.258
# 1723138 2010-03-27 2022-10-31 08:22:00                0.348
# 175594  2007-04-17 2022-10-31 15:58:00                0.164
# 920574  2008-09-16 2022-10-31 00:18:00                0.204
# 1741570 2010-09-04 2022-10-31 03:34:00                0.330
#
#          Global_reactive_power  Voltage  Global_intensity  Sub_metering_1  \
# 245473                   0.094   236.03               1.0             0.0
# 1723138                  0.000   241.31               1.4             0.0
# 175594                   0.000   243.72               0.8             0.0
# 920574                   0.000   244.45               1.0             0.0
# 1741570                  0.102   241.66               1.4             0.0
#
#          Sub_metering_2  Sub_metering_3  year  month  days      time  Hour  \
# 245473              1.0             0.0  2007      5     6  04:37:00     4
# ...

# %% [markdown]
# # drop Date,Time,time,sub_metering_1,sub_metering_2,sub_metering_3

# %%
df.drop(['Date','Time','time','Sub_metering_1','Sub_metering_2','Sub_metering_3'],axis=1,inplace=True)

# %%
df
# Out:
#          Global_active_power  Global_reactive_power  Voltage  \
# 245473                 0.258                  0.094   236.03
# 1723138                0.348                  0.000   241.31
# 175594                 0.164                  0.000   243.72
# 920574                 0.204                  0.000   244.45
# 1741570                0.330                  0.102   241.66
# ...                      ...                    ...      ...
# 147883                 1.418                  0.202   237.45
# 384656                 1.558                  0.170   237.66
# 1752127                0.420                  0.186   240.95
# 1319633                0.312                  0.222   242.06
# 1691350                0.540                  0.112   244.77
#
#          Global_intensity  year  month  days  Hour  minutes  Total_metering
# 245473                1.0  2007      5     6     4       37             1.0
# 1723138               1.4  2010      3    27     8       22             0.0
# ...

# %%
df.describe()
# Out:
#        Global_active_power  Global_reactive_power       Voltage  \
# count         49366.000000           49366.000000  49366.000000
# mean              1.082322               0.123250    240.844731
# std               1.044202               0.112627      3.226085
# min               0.078000               0.000000    225.430000
# 25%               0.308000               0.048000    239.010000
# 50%               0.594000               0.100000    241.030000
# 75%               1.524000               0.194000    242.870000
# max               9.656000               0.996000    252.670000
#
#        Global_intensity          year         month          days  \
# count      49366.000000  49366.000000  49366.000000  49366.000000
# mean           4.588583   2008.426326      6.511121     15.663675
# std            4.389418      1.122711      3.448897      8.836561
# min            0.200000   2006.000000      1.000000      1.000000
# ...

# %%
df.corr()
# Out:
#                        Global_active_power  Global_reactive_power   Voltage  \
# Global_active_power               1.000000               0.244186 -0.396195
# Global_reactive_power             0.244186               1.000000 -0.108601
# Voltage                          -0.396195              -0.108601  1.000000
# Global_intensity                  0.998857               0.263162 -0.407957
# year                             -0.036623               0.041943  0.253498
# month                             0.011230               0.012658  0.041283
# days                             -0.008392               0.009295  0.000746
# Hour                              0.283500               0.120962 -0.172533
# minutes                          -0.002445              -0.003001  0.013777
# Total_metering                    0.841000               0.175117 -0.340608
#
#                        Global_intensity      year     month      days  \
# ...

# %% [markdown]
# # Univariate Analysis

# %%
numerical_feature=[feature for feature in df.columns if df[feature].dtype!='O']

# %%
for feature in numerical_feature:
    plt.hist(x=feature,color='g',data=df)
    plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
import seaborn as sns
for feature in numerical_feature:
    sns.scatterplot(data=df,x=feature,y='Total_metering')
    plt.show()

# %% [markdown]
# # Find outlier

# %%
for feature in numerical_feature:
    sns.boxplot(data=df,x=feature,color='r')
    plt.show()

# %% [markdown]
# # Multivariate analysis

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# # Independent and dependent feature

# %%
x=df.drop(['Total_metering'],axis=1)

# %%
x
# Out:
#          Global_active_power  Global_reactive_power  Voltage  \
# 538732                 1.778                  0.134   237.50
# 1937190                0.248                  0.072   243.49
# 918949                 1.842                  0.000   238.42
# 548866                 2.996                  0.074   236.57
# 1420951                1.346                  0.092   238.59
# ...                      ...                    ...      ...
# 640081                 0.290                  0.076   242.41
# 1497346                1.070                  0.300   242.18
# 403896                 1.326                  0.198   239.50
# 1240485                0.292                  0.000   244.40
# 62198                  1.386                  0.138   238.41
#
#          Global_intensity  year  month  days  Hour  minutes
# 538732                7.4  2007     12    25    20       16
# 1937190               1.0  2010      8    22    23       54
# ...

# %%
y=df['Total_metering']

# %%
y
# Out:
# 538732      0.0
# 1937190     1.0
# 918949      1.0
# 548866     19.0
# 1420951    18.0
#            ...
# 640081      0.0
# 1497346    12.0
# 403896     18.0
# 1240485     1.0
# 62198       0.0
# Name: Total_metering, Length: 49395, dtype: float64

# %% [markdown]
# # Split train and test data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=10)

# %%
x_train.shape
# Out:
# (34576, 9)

# %%
y_train.shape
# Out:
# (34576,)

# %%
x_test.shape
# Out:
# (14819, 9)

# %%
y_test.shape
# Out:
# (14819,)

# %% [markdown]
# # Feature Scaling or Standardized the dataset

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
x_train
# Out:
# array([[-0.71255772, -0.05187507,  2.22141759, ...,  0.71704015,
#         -0.93823011,  0.90021767],
#        [ 1.23834784, -0.58129809, -1.15530044, ..., -0.64522221,
#          1.37063272, -0.48717771],
#        [ 0.40305173, -0.61659296,  1.39490517, ..., -1.55339712,
#         -0.79392618,  0.14871184],
#        ...,
#        [ 0.31651204, -0.54600322, -0.21510415, ..., -1.32635339,
#         -0.50531833,  0.61117697],
#        [-0.75018367,  0.88343895, -0.69749244, ...,  0.2629527 ,
#         -0.3610144 ,  0.20651998],
#        [-0.44165087,  0.75990691, -0.28884504, ..., -0.9857878 ,
#          1.22632879,  0.49556069]])

# %%
x_test
# Out:
# array([[-0.27985928, -1.09307368, -0.00617164, ..., -1.21283153,
#         -0.64962226, -1.64334052],
#        [ 0.11145061,  3.84820789, -0.10142029, ...,  1.62521506,
#          0.79341701, -0.14032886],
#        [-0.73513329,  0.75990691,  0.4055483 , ...,  0.71704015,
#         -1.65974974,  1.0736421 ],
#        ...,
#        [ 0.79059903, -0.52835579,  0.47621665, ...,  1.73873693,
#         -0.21671048, -1.70114866],
#        [-0.80286   , -1.09307368,  0.36867786, ...,  0.71704015,
#          1.65924057, -1.06525911],
#        [ 1.06526847, -0.51070835, -1.23211386, ...,  1.05760575,
#         -1.51544582,  0.03309556]])

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg_pred=reg.predict(x_test)

# %%
reg_pred
# Out:
# array([ 7.88406732,  8.91483751,  2.14627479, ..., 19.25206223,
#        -1.49610202, 22.95474044])

# %%
print(reg.coef_)
# Out:
# [ 21.84253456  -0.19131032  -0.52361032 -10.54130321   0.64969906
#   -0.02433959   0.05666987  -1.08063675  -0.04647248]

# %%
print(reg.intercept_)
# Out:
# 8.884168209162423

# %% [markdown]
# # Prediction for test data

# %%
reg_pred=reg.predict(x_test)

# %%
reg_pred
# Out:
# array([ 7.88406732,  8.91483751,  2.14627479, ..., 19.25206223,
#        -1.49610202, 22.95474044])

# %% [markdown]
# # Assumption of Linear Regression

# %%
plt.scatter(y_test,reg_pred)
plt.xlabel("Test Truth Data")
plt.ylabel("Test predicted Data")
# Out:
# Text(0, 0.5, 'Test predicted Data')

# %% [markdown]
# # Residuals(Error)

# %%
residuals=y_test-reg_pred

# %%
residuals
# Out:
# 1787857    -6.884067
# 1860483    -7.914838
# 1322364    -1.146275
# 1554589   -23.087355
# 1776560     3.939561
#              ...
# 572720      5.825948
# 1006737    -8.551105
# 1118436     0.747938
# 1279067     2.496102
# 141606    -22.954740
# Name: Total_metering, Length: 14819, dtype: float64

# %%
sns.distplot(residuals,kde=True)

# %%
plt.scatter(reg_pred,residuals)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
print(mean_absolute_error(y_test,reg_pred))
print(mean_squared_error(y_test,reg_pred))
print(np.sqrt(mean_squared_error(y_test,reg_pred)))
# Out:
# 4.252905022502147
# 42.96821057921147
# 6.5550141555309756

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,reg_pred)
print(score)
# Out:
# 0.7462107389236778

# %% [markdown]
# Adjusted R2

# %%
1-(1-score)*len(y_test)/(len(y_test)-x_test.shape[1]-1)
# Out:
# 0.7460393639077576

# %% [markdown]
# # Observation:
#     Linear Regression:Accuracy score is 74%

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import Ridge

# %%
rdg=Ridge()

# %%
rdg
# Out:
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
rdg.fit(x_train,y_train)
# Out:
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
print(rdg.coef_)
# Out:
# [21.29162512 -0.20244745 -0.51635476 -9.98485045  0.65076624 -0.02414075
#   0.05669053 -1.07971924 -0.04672208]

# %%
print(rdg.intercept_)
# Out:
# 8.884168209162423

# %%
rdg_pred=rdg.predict(x_test)
rdg
# Out:
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %% [markdown]
# # Assumption:1

# %%
plt.scatter(y_test,rdg_pred)
plt.xlabel("Test Truth data")
plt.ylabel("predict data")
# Out:
# Text(0, 0.5, 'predict data')

# %% [markdown]
# # Assumption:2

# %%
residuals=y_test-rdg_pred

# %%
residuals
# Out:
# 1787857    -6.877280
# 1860483    -7.911334
# 1322364    -1.145777
# 1554589   -23.092284
# 1776560     3.958317
#              ...
# 572720      5.829205
# 1006737    -8.538654
# 1118436     0.775670
# 1279067     2.485192
# 141606    -22.933954
# Name: Total_metering, Length: 14819, dtype: float64

# %%
sns.distplot(residuals,kde=True)

# %% [markdown]
# # Assumption:3

# %%
plt.scatter(y_test,residuals)

# %% [markdown]
# # Performance metrics

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
print(mean_squared_error(y_test,rdg_pred))
print(mean_absolute_error(y_test,rdg_pred))
print(np.sqrt(mean_squared_error(y_test,rdg_pred)))
# Out:
# 42.972292296901536
# 4.254014754228742
# 6.555325491301064

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,rdg_pred)

# %%
score
# Out:
# 0.7461866304932238

# %% [markdown]
# # Adjusted R2

# %%
1-(1-score)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
# Out:
# 0.7460323783272733

# %% [markdown]
# # Obesrvation:
#     Ridge Rgression:Accuracy is 74%

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.linear_model import Lasso

# %%
las=Lasso()

# %%
las
# Out:
# Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
las.fit(x_train,y_train)
# Out:
# Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
print(las.coef_)
# Out:
# [10.14957546 -0.         -0.          0.          0.         -0.
#  -0.         -0.         -0.        ]

# %%
print(las.intercept_)
# Out:
# 8.884168209162423

# %%
las_pred=las.predict(x_test)

# %%
las_pred
# Out:
# array([ 6.04371533, 10.0153446 ,  1.42287744, ..., 16.90841269,
#         0.73548007, 19.69619093])

# %% [markdown]
# # Assumption:1

# %%
plt.scatter(y_test,las_pred)
plt.xlabel("Test Truth data")
plt.ylabel("predict data")
# Out:
# Text(0, 0.5, 'predict data')

# %% [markdown]
# # Assumption:2

# %%
residuals=y_test-las_pred

# %%
residuals
# Out:
# 1787857    -5.043715
# 1860483    -9.015345
# 1322364    -0.422877
# 1554589   -18.002784
# 1776560     6.507296
#              ...
# 572720      6.903369
# 1006737    -9.576174
# 1118436     3.091587
# 1279067     0.264520
# 141606    -19.696191
# Name: Total_metering, Length: 14819, dtype: float64

# %%
sns.distplot(residuals,kde=True)

# %% [markdown]
# # Assumption:3

# %%
plt.scatter(residuals,las_pred)

# %% [markdown]
# # Performance metrics

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
print(mean_squared_error(y_test,las_pred))
print(mean_absolute_error(y_test,las_pred))
print(np.sqrt(mean_squared_error(y_test,las_pred)))
# Out:
# 45.771131227096866
# 4.383336202875468
# 6.765436514157595

# %%
from sklearn.metrics import r2_score

# %%
score=r2_score(y_test,las_pred)

# %%
score
# Out:
# 0.7296554495482678

# %% [markdown]
# Adjusted R2

# %%
1-(1-score)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
# Out:
# 0.7294911507465887

# %% [markdown]
# # Observation:
#     Lasso Regression:Accuracy is 72%

# %% [markdown]
# # ElasticNet regression

# %%
from sklearn.linear_model import ElasticNet

# %%
elas=ElasticNet()

# %%
elas
# Out:
# ElasticNet(alpha=1.0, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#            max_iter=1000, normalize=False, positive=False, precompute=False,
#            random_state=None, selection='cyclic', tol=0.0001, warm_start=False)

# %%
elas.fit(x_train,y_train)
# Out:
# ElasticNet(alpha=1.0, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#            max_iter=1000, normalize=False, positive=False, precompute=False,
#            random_state=None, selection='cyclic', tol=0.0001, warm_start=False)

# %%
elas_pred=elas.predict(x_test)

# %%
elas_pred
# Out:
# array([ 6.4865274 , 10.22018978,  2.66147153, ..., 15.00537236,
#         2.02106569, 18.11582044])

# %%
elas.coef_
# Out:
# array([ 4.22409548,  0.        , -0.44277343,  4.14205063,  0.05811428,
#        -0.        , -0.        , -0.        , -0.        ])

# %%
elas.intercept_
# Out:
# 8.884168209162421

# %% [markdown]
# # Assumption:1

# %%
plt.scatter(y_test,elas_pred)
plt.xlabel("Test Truth data")
plt.ylabel("predict data")
# Out:
# Text(0, 0.5, 'predict data')

# %% [markdown]
# # Assumption:2

# %%
residuals=y_test-elas_pred

# %%
residuals
# Out:
# 1787857    -5.486527
# 1860483    -9.220190
# 1322364    -1.661472
# 1554589   -13.394496
# 1776560     6.011421
#              ...
# 572720      7.032552
# 1006737    -9.496352
# 1118436     4.994628
# 1279067    -1.021066
# 141606    -18.115820
# Name: Total_metering, Length: 14819, dtype: float64

# %%
sns.distplot(residuals,kde=True)

# %% [markdown]
# # Assumption:3

# %%
plt.scatter(residuals,elas_pred)

# %% [markdown]
# # Performance metrics

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
print(mean_squared_error(y_test,elas_pred))
print(mean_absolute_error(y_test,elas_pred))
print(np.sqrt(mean_squared_error(y_test,elas_pred)))
# Out:
# 52.11077408254525
# 5.009915166459501
# 7.218779265398357

# %%
from sklearn.metrics import r2_score

# %%
score=r2_score(y_test,elas_pred)

# %%
score
# Out:
# 0.6922107141477563

# %% [markdown]
# #Adjusted R2

# %%
1-(1-score)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
# Out:
# 0.6920236587373525

# %% [markdown]
# # Observation:
# ElasticNet Regression:Accuracy is 69%
